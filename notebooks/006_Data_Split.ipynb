# %% [markdown]
# # Aim
#
# 1. Data split into train and test

# %%
import os
from datetime import datetime

import numpy as np
import pandas as pd

# %%
DATA_ROOT = f"../data"

# %%
df = pd.read_pickle(f"{DATA_ROOT}/fselect/accidents_raw.pkl")

# %%
df.head(3)
# Out:
#     ID    Source    TMC          Start_Time  Distance(mi)  \
# 0  A-1  MapQuest  201.0 2016-02-08 05:46:00          0.01
# 1  A-2  MapQuest  201.0 2016-02-08 06:07:59          0.01
# 2  A-3  MapQuest  201.0 2016-02-08 06:49:27          0.01
#
#                                          Description Side          City  \
# 0  Right lane blocked due to accident on I-70 Eas...    R        Dayton
# 1  Accident on Brice Rd at Tussing Rd. Expect del...    L  Reynoldsburg
# 2  Accident on OH-32 State Route 32 Westbound at ...    R  Williamsburg
#
#        County State  ... Station   Stop Traffic_Calming  Traffic_Signal  \
# 0  Montgomery    OH  ...   False  False           False           False
# 1    Franklin    OH  ...   False  False           False           False
# 2    Clermont    OH  ...   False  False           False            True
#
#    Turning_Loop  Sunrise_Sunset  Civil_Twilight Nautical_Twilight  \
# 0         False           Night           Night             Night
# 1         False           Night           Night             Night
# 2         False           Night           Night               Day
#
#    Astronomical_Twilight Severity
# 0                  Night        3
# 1                    Day        2
# 2                    Day        2
#
# [3 rows x 38 columns]

# %%
# convert time to datetime
df["Start_Time"] = pd.to_datetime(df["Start_Time"])

# The task is to predict the impact of accident on traffic from January 2020 to June 2020
df = df.sort_values(by=["Start_Time"], ascending=True, ignore_index=True)

# %%
test_data_start_date = pd.to_datetime("2020-01-01")
test_data_end_date = pd.to_datetime("2020-07-01")
print(test_data_end_date)
# Out:
# 2020-07-01 00:00:00

# %%
df
# Out:
#                 ID    Source    TMC          Start_Time  Distance(mi)  \
# 0        A-2478859      Bing    0.0 2016-02-08 00:37:08         3.230
# 1              A-1  MapQuest  201.0 2016-02-08 05:46:00         0.010
# 2        A-2478860      Bing    0.0 2016-02-08 05:56:20         0.747
# 3              A-2  MapQuest  201.0 2016-02-08 06:07:59         0.010
# 4        A-2478861      Bing    0.0 2016-02-08 06:15:39         0.055
# ...            ...       ...    ...                 ...           ...
# 3513612   A-560284  MapQuest  201.0 2020-06-30 22:51:25         0.000
# 3513613   A-561183  MapQuest  241.0 2020-06-30 22:52:02         0.000
# 3513614   A-561279  MapQuest  201.0 2020-06-30 22:52:37         0.000
# 3513615   A-561184  MapQuest  241.0 2020-06-30 22:56:52         0.000
# 3513616   A-560480  MapQuest  201.0 2020-06-30 23:18:09         0.000
#
#                                                Description Side          City  \
# 0        Between Sawmill Rd/Exit 20 and OH-315/Olentang...    R        Dublin
# 1        Right lane blocked due to accident on I-70 Eas...    R        Dayton
# 2                       At OH-4/OH-235/Exit 41 - Accident.    R        Dayton
# 3        Accident on Brice Rd at Tussing Rd. Expect del...    L  Reynoldsburg
# 4                         At I-71/US-50/Exit 1 - Accident.    R    Cincinnati
# ...                                                    ...  ...           ...
# 3513612  Right lane blocked due to accident on I-195 We...    R    Providence
# 3513613  Lane blocked due to accident on Dallas North T...    R        Dallas
# 3513614  Accident on US-31A Nolensville Pike at Allied Dr.    R     Nashville
# 3513615  Lane blocked due to accident on I-30 Westbound...    R        Dallas
# 3513616  Accident on I-264 Watterson Expy Westbound at ...    R    Louisville
#
#              County State  ... Station   Stop Traffic_Calming  Traffic_Signal  \
# 0          Franklin    OH  ...   False  False           False           False
# 1        Montgomery    OH  ...   False  False           False           False
# 2        Montgomery    OH  ...   False  False           False           False
# 3          Franklin    OH  ...   False  False           False           False
# 4          Hamilton    OH  ...   False  False           False           False
# ...             ...   ...  ...     ...    ...             ...             ...
# 3513612  Providence    RI  ...   False  False           False           False
# 3513613      Dallas    TX  ...   False  False           False           False
# 3513614    Davidson    TN  ...   False  False           False            True
# 3513615      Dallas    TX  ...   False  False           False           False
# 3513616   Jefferson    KY  ...   False  False           False           False
#
#          Turning_Loop  Sunrise_Sunset  Civil_Twilight Nautical_Twilight  \
# 0               False           Night           Night             Night
# 1               False           Night           Night             Night
# 2               False           Night           Night             Night
# 3               False           Night           Night             Night
# 4               False           Night           Night             Night
# ...               ...             ...             ...               ...
# 3513612         False           Night           Night             Night
# 3513613         False           Night           Night             Night
# 3513614         False           Night           Night             Night
# 3513615         False           Night           Night             Night
# 3513616         False           Night           Night             Night
#
#          Astronomical_Twilight Severity
# 0                        Night        3
# 1                        Night        3
# 2                        Night        2
# 3                          Day        2
# 4                          Day        2
# ...                        ...      ...
# 3513612                  Night        3
# 3513613                  Night        2
# 3513614                  Night        2
# 3513615                  Night        3
# 3513616                  Night        3
#
# [3513617 rows x 38 columns]

# %%
df_test = df[
    (df["Start_Time"] >= test_data_start_date) & (df["Start_Time"] < test_data_end_date)
]

df_test.shape
# Out:
# (539187, 38)

# %%
df_train = df.iloc[~df.index.isin(df_test.index)]

df_train.shape
# Out:
# (2974430, 38)

# %%
# check if train test split has any intersections

set(df_train["ID"]).intersection(set(df_test["ID"]))
# Out:
# set()

# %%
os.makedirs(f"{DATA_ROOT}/train/raw/", exist_ok=True)
os.makedirs(f"{DATA_ROOT}/test/raw/", exist_ok=True)

# %%
df_train.reset_index(drop=True).to_pickle(f"{DATA_ROOT}/train/raw/data.pkl")
df_test.reset_index(drop=True).to_pickle(f"{DATA_ROOT}/test/raw/data.pkl")
